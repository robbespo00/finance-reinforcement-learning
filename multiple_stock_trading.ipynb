# %% [markdown]
# <a href="https://colab.research.google.com/github/robbespo00/finance_reinforcement_learning/blob/main/multiple_stock_trading.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Multiple Stock Trading**

# %%
! pip install yfinance &> /dev/null
! pip install stockstats &> /dev/null
! pip install stable-baselines[mpi] &> /dev/null
! pip install tensorflow==1.15.4 &> /dev/null
! pip install git+https://github.com/AI4Finance-Foundation/FinRL.git &> /dev/null

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime

# %matplotlib inline
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent
from finrl.meta.data_processor import DataProcessor

from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline
from pprint import pprint

import sys
sys.path.append("../FinRL")

import itertools

from finrl import config
from finrl import config_tickers
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)

TRAIN_START_DATE = '2009-01-01'
TRAIN_END_DATE = '2020-07-01'
TRADE_START_DATE = '2020-07-01'
TRADE_END_DATE = '2021-10-31'

# %%
df = YahooDownloader(start_date=TRAIN_START_DATE,
                     end_date=TRADE_END_DATE,
                     ticker_list=config_tickers.DOW_30_TICKER).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (94331, 8)

# %%
print(config_tickers.DOW_30_TICKER)
# Out:
# ['AXP', 'AMGN', 'AAPL', 'BA', 'CAT', 'CSCO', 'CVX', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'KO', 'JPM', 'MCD', 'MMM', 'MRK', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'CRM', 'VZ', 'V', 'WBA', 'WMT', 'DIS', 'DOW']

# %%
df.sort_values(['date','tic'],ignore_index=True).head()
# Out:
#          date       open       high        low      close     volume   tic  \
# 0  2009-01-02   3.067143   3.251429   3.041429   2.771174  746015200  AAPL
# 1  2009-01-02  58.590000  59.080002  57.750000  44.867599    6547900  AMGN
# 2  2009-01-02  18.570000  19.520000  18.400000  15.477421   10955700   AXP
# 3  2009-01-02  42.799999  45.560001  42.779999  33.941101    7010200    BA
# 4  2009-01-02  44.910000  46.980000  44.709999  31.942253    7117200   CAT
#
#    day
# 0    4
# 1    4
# 2    4
# 3    4
# 4    4

# %%
fe = FeatureEngineer(
    use_technical_indicator=True,
    tech_indicator_list=INDICATORS,
    use_vix=True,
    use_turbulence=True,
    user_defined_feature=False
)

processed = fe.preprocess_data(df)
# Out:
# Successfully added technical indicators
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (3229, 8)
# Successfully added vix
# Successfully added turbulence index

# %%
list_ticker = processed['tic'].unique().tolist()
list_date = list(pd.date_range(processed['date'].min(), processed['date'].max()).astype(str))
combination = list(itertools.product(list_date,list_ticker))

processed_full = pd.DataFrame(combination, columns=['date','tic']).merge(processed, on=['date','tic'],how='left')
processed_full = processed_full[processed_full['date'].isin(processed['date'])]
processed_full = processed_full.sort_values(['date','tic'])

processed_full = processed_full.fillna(0)

# %%
processed_full.sort_values(['date','tic'], ignore_index=True).head(10)
# Out:
#          date   tic       open       high        low      close       volume  \
# 0  2009-01-02  AAPL   3.067143   3.251429   3.041429   2.771174  746015200.0
# 1  2009-01-02  AMGN  58.590000  59.080002  57.750000  44.867599    6547900.0
# 2  2009-01-02   AXP  18.570000  19.520000  18.400000  15.477421   10955700.0
# 3  2009-01-02    BA  42.799999  45.560001  42.779999  33.941101    7010200.0
# 4  2009-01-02   CAT  44.910000  46.980000  44.709999  31.942253    7117200.0
# 5  2009-01-02   CRM   8.025000   8.550000   7.912500   8.505000    4069200.0
# 6  2009-01-02  CSCO  16.410000  17.000000  16.250000  12.155674   40980600.0
# 7  2009-01-02   CVX  74.230003  77.300003  73.580002  44.807617   13695900.0
# 8  2009-01-02   DIS  22.760000  24.030001  22.500000  20.597498    9796600.0
# 9  2009-01-02    GS  84.019997  87.620003  82.190002  70.735062   14088500.0
#
#    day  macd   boll_ub   boll_lb  rsi_30     cci_30  dx_30  close_30_sma  \
# 0  4.0   0.0  2.995051  2.664252   100.0  66.666667  100.0      2.771174
# 1  4.0   0.0  2.995051  2.664252   100.0  66.666667  100.0     44.867599
# 2  4.0   0.0  2.995051  2.664252   100.0  66.666667  100.0     15.477421
# 3  4.0   0.0  2.995051  2.664252   100.0  66.666667  100.0     33.941101
# 4  4.0   0.0  2.995051  2.664252   100.0  66.666667  100.0     31.942253
# 5  4.0   0.0  2.995051  2.664252   100.0  66.666667  100.0      8.505000
# 6  4.0   0.0  2.995051  2.664252   100.0  66.666667  100.0     12.155674
# 7  4.0   0.0  2.995051  2.664252   100.0  66.666667  100.0     44.807617
# 8  4.0   0.0  2.995051  2.664252   100.0  66.666667  100.0     20.597498
# 9  4.0   0.0  2.995051  2.664252   100.0  66.666667  100.0     70.735062
#
#    close_60_sma        vix  turbulence
# 0      2.771174  39.189999         0.0
# 1     44.867599  39.189999         0.0
# 2     15.477421  39.189999         0.0
# 3     33.941101  39.189999         0.0
# 4     31.942253  39.189999         0.0
# 5      8.505000  39.189999         0.0
# 6     12.155674  39.189999         0.0
# 7     44.807617  39.189999         0.0
# 8     20.597498  39.189999         0.0
# 9     70.735062  39.189999         0.0

# %%
train = data_split(processed_full, TRAIN_START_DATE, TRAIN_END_DATE)
trade = data_split(processed_full, TRADE_START_DATE, TRADE_END_DATE)

print(len(train))
print(len(trade))
# Out:
# 83897
# 9744

# %%
train.tail()
# Out:
#             date  tic        open        high         low       close  \
# 2892  2020-06-30  UNH  288.570007  296.450012  287.660004  286.754181
# 2892  2020-06-30    V  191.490005  193.750000  190.160004  190.737228
# 2892  2020-06-30   VZ   54.919998   55.290001   54.360001   49.750820
# 2892  2020-06-30  WBA   42.119999   42.580002   41.759998   39.035736
# 2892  2020-06-30  WMT  119.220001  120.129997  118.540001  116.121765
#
#           volume  day      macd     boll_ub     boll_lb     rsi_30     cci_30  \
# 2892   2932900.0  1.0 -0.019415  302.845890  270.287334  52.413049 -25.866269
# 2892   9040100.0  1.0  1.048785  198.750523  185.041397  53.021030 -51.550912
# 2892  17414800.0  1.0 -0.431680   53.248501   48.123872  48.097030 -51.065600
# 2892   4782100.0  1.0 -0.083986   42.609308   36.487093  48.830190 -14.508045
# 2892   6836400.0  1.0 -0.886569  119.473766  113.510451  48.159664 -69.938813
#
#          dx_30  close_30_sma  close_60_sma    vix  turbulence
# 2892  1.846804    286.997200    280.002895  30.43   12.918722
# 2892  2.013358    191.485036    181.677682  30.43   12.918722
# 2892  8.508886     50.378309     50.825242  30.43   12.918722
# 2892  1.500723     39.135189     38.935129  30.43   12.918722
# 2892  3.847271    117.787627    119.723274  30.43   12.918722

# %%
trade.head()
# Out:
#          date   tic        open        high         low       close  \
# 0  2020-07-01  AAPL   91.279999   91.839996   90.977501   89.904602
# 0  2020-07-01  AMGN  235.520004  256.230011  232.580002  240.153946
# 0  2020-07-01   AXP   95.250000   96.959999   93.639999   91.743057
# 0  2020-07-01    BA  185.880005  190.610001  180.039993  180.320007
# 0  2020-07-01   CAT  129.380005  129.399994  125.879997  119.817108
#
#         volume  day      macd     boll_ub     boll_lb     rsi_30      cci_30  \
# 0  110737200.0  2.0  3.014603   92.699319   80.179951  62.807128  107.491876
# 0    6575800.0  2.0  3.636391  232.397415  200.212954  61.279620  271.386137
# 0    3301000.0  2.0 -0.387710  110.012237   87.432137  48.504825  -66.320992
# 0   49036700.0  2.0  5.443193  220.721139  160.932863  50.925771   24.220608
# 0    2807800.0  2.0  1.263827  129.720776  112.569085  52.865417   35.633512
#
#        dx_30  close_30_sma  close_60_sma        vix  turbulence
# 0  29.730532     83.933767     77.717543  28.620001   53.068043
# 0  46.806139    214.858661    215.931665  28.620001   53.068043
# 0   3.142448     96.882072     90.357376  28.620001   53.068043
# 0  15.932920    176.472335    155.614168  28.620001   53.068043
# 0  14.457404    118.586880    112.860601  28.620001   53.068043

# %%
INDICATORS
# Out:
# ['macd',
#  'boll_ub',
#  'boll_lb',
#  'rsi_30',
#  'cci_30',
#  'dx_30',
#  'close_30_sma',
#  'close_60_sma']

# %%
stock_dimension = len(train.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 29, State Space: 291

# %%
buy_cost_list = sell_cost_list = [0.001] * stock_dimension
num_stock_shares = [0] * stock_dimension

env_kwargs = {
    "hmax": 100,
    "initial_amount": 1000000,
    "num_stock_shares": num_stock_shares,
    "buy_cost_pct": buy_cost_list,
    "sell_cost_pct": sell_cost_list,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4
}


e_train_gym = StockTradingEnv(df = train, **env_kwargs)

# %%
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))
# Out:
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>

# %%
agent = DRLAgent(env = env_train)

# %% [markdown]
# # **1) Actor Critic Method**

# %% [markdown]
# $$\nabla_{\theta} J(\theta) = \mathbb{E}_{\tau} \left[ \sum_{t=0}^{T-1} \nabla_{\theta} \log \pi_{\theta}(a_t|s_t)Q_w (s_t,a_t) \right]$$

# %%
agent = DRLAgent(env = env_train)
model_a2c = agent.get_model("a2c")
# Out:
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0007}
# Using cuda device

# %%
trained_a2c = agent.train_model(model=model_a2c, 
                             tb_log_name='a2c',
                             total_timesteps=50000)
# Out:
# ---------------------------------------
# | time/                 |             |
# |    fps                | 62          |
# |    iterations         | 100         |
# |    time_elapsed       | 7           |
# |    total_timesteps    | 500         |
# | train/                |             |
# |    entropy_loss       | -41.2       |
# |    explained_variance | 5.96e-08    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 99          |
# |    policy_loss        | 25.7        |
# |    reward             | 0.038072154 |
# |    std                | 1           |
# |    value_loss         | 0.767       |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 76         |
# |    iterations         | 200        |
# |    time_elapsed       | 13         |
# |    total_timesteps    | 1000       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | -0.00794   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 199        |
# |    policy_loss        | -25.3      |
# |    reward             | -1.6664015 |
# |    std                | 1          |
# |    value_loss         | 1.19       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 80        |
# |    iterations         | 300       |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | -0.0902   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 299       |
# |    policy_loss        | -278      |
# |    reward             | 4.5007186 |
# |    std                | 1         |
# |    value_loss         | 46.6      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 83        |
# |    iterations         | 400       |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 399       |
# |    policy_loss        | 7.31      |
# |    reward             | 5.3049793 |
# |    std                | 1         |
# |    value_loss         | 3.65      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 86        |
# |    iterations         | 500       |
# |    time_elapsed       | 28        |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 499       |
# |    policy_loss        | 388       |
# |    reward             | -5.122654 |
# |    std                | 1         |
# |    value_loss         | 131       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 88        |
# |    iterations         | 600       |
# |    time_elapsed       | 33        |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0.0881    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 599       |
# |    policy_loss        | 101       |
# |    reward             | 0.1573371 |
# |    std                | 1         |
# |    value_loss         | 6.04      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 89         |
# |    iterations         | 700        |
# |    time_elapsed       | 39         |
# |    total_timesteps    | 3500       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 699        |
# |    policy_loss        | -58.8      |
# |    reward             | -1.7995613 |
# |    std                | 1          |
# |    value_loss         | 2.71       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 88        |
# |    iterations         | 800       |
# |    time_elapsed       | 45        |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 799       |
# |    policy_loss        | 76.4      |
# |    reward             | -2.372561 |
# |    std                | 1         |
# |    value_loss         | 4.3       |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 87         |
# |    iterations         | 900        |
# |    time_elapsed       | 51         |
# |    total_timesteps    | 4500       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 899        |
# |    policy_loss        | 111        |
# |    reward             | -1.0131671 |
# |    std                | 1.01       |
# |    value_loss         | 7.33       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 87        |
# |    iterations         | 1000      |
# |    time_elapsed       | 56        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | -26.5     |
# |    reward             | -5.250077 |
# |    std                | 1.01      |
# |    value_loss         | 0.749     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 88        |
# |    iterations         | 1100      |
# |    time_elapsed       | 61        |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1099      |
# |    policy_loss        | -226      |
# |    reward             | 2.4161067 |
# |    std                | 1.01      |
# |    value_loss         | 36.7      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 88        |
# |    iterations         | 1200      |
# |    time_elapsed       | 68        |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | -0.0976   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1199      |
# |    policy_loss        | -92.1     |
# |    reward             | 0.3326944 |
# |    std                | 1.01      |
# |    value_loss         | 6.21      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 88         |
# |    iterations         | 1300       |
# |    time_elapsed       | 73         |
# |    total_timesteps    | 6500       |
# | train/                |            |
# |    entropy_loss       | -41.5      |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1299       |
# |    policy_loss        | -11.3      |
# |    reward             | -3.5042982 |
# |    std                | 1.01       |
# |    value_loss         | 2.82       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 89        |
# |    iterations         | 1400      |
# |    time_elapsed       | 78        |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | 0.038     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | 31.5      |
# |    reward             | 1.1067637 |
# |    std                | 1.01      |
# |    value_loss         | 1.79      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 89        |
# |    iterations         | 1500      |
# |    time_elapsed       | 83        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | -0.0172   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | 106       |
# |    reward             | 3.5897276 |
# |    std                | 1.01      |
# |    value_loss         | 7.78      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 89        |
# |    iterations         | 1600      |
# |    time_elapsed       | 89        |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | 133       |
# |    reward             | 3.0989976 |
# |    std                | 1.01      |
# |    value_loss         | 13.7      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 89          |
# |    iterations         | 1700        |
# |    time_elapsed       | 94          |
# |    total_timesteps    | 8500        |
# | train/                |             |
# |    entropy_loss       | -41.4       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1699        |
# |    policy_loss        | -82         |
# |    reward             | -0.62729806 |
# |    std                | 1.01        |
# |    value_loss         | 20.3        |
# ---------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 89       |
# |    iterations         | 1800     |
# |    time_elapsed       | 100      |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -41.4    |
# |    explained_variance | -6.35    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | 62.4     |
# |    reward             | 3.260614 |
# |    std                | 1.01     |
# |    value_loss         | 5.07     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 89         |
# |    iterations         | 1900       |
# |    time_elapsed       | 105        |
# |    total_timesteps    | 9500       |
# | train/                |            |
# |    entropy_loss       | -41.4      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1899       |
# |    policy_loss        | 1.41       |
# |    reward             | 0.18683845 |
# |    std                | 1.01       |
# |    value_loss         | 0.914      |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 90          |
# |    iterations         | 2000        |
# |    time_elapsed       | 110         |
# |    total_timesteps    | 10000       |
# | train/                |             |
# |    entropy_loss       | -41.4       |
# |    explained_variance | -1.05       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1999        |
# |    policy_loss        | -41.9       |
# |    reward             | -0.31503755 |
# |    std                | 1.01        |
# |    value_loss         | 1.87        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 90        |
# |    iterations         | 2100      |
# |    time_elapsed       | 115       |
# |    total_timesteps    | 10500     |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2099      |
# |    policy_loss        | 60.2      |
# |    reward             | 0.9686291 |
# |    std                | 1.01      |
# |    value_loss         | 5.28      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 91         |
# |    iterations         | 2200       |
# |    time_elapsed       | 120        |
# |    total_timesteps    | 11000      |
# | train/                |            |
# |    entropy_loss       | -41.4      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2199       |
# |    policy_loss        | 21.6       |
# |    reward             | -7.9197507 |
# |    std                | 1.01       |
# |    value_loss         | 3.2        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 90         |
# |    iterations         | 2300       |
# |    time_elapsed       | 126        |
# |    total_timesteps    | 11500      |
# | train/                |            |
# |    entropy_loss       | -41.4      |
# |    explained_variance | -0.01      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2299       |
# |    policy_loss        | -1.97e+03  |
# |    reward             | -1.1841738 |
# |    std                | 1.01       |
# |    value_loss         | 2.39e+03   |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 90        |
# |    iterations         | 2400      |
# |    time_elapsed       | 131       |
# |    total_timesteps    | 12000     |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | -0.096    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2399      |
# |    policy_loss        | 2.19      |
# |    reward             | 1.0953976 |
# |    std                | 1.01      |
# |    value_loss         | 2.73      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 91         |
# |    iterations         | 2500       |
# |    time_elapsed       | 136        |
# |    total_timesteps    | 12500      |
# | train/                |            |
# |    entropy_loss       | -41.4      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2499       |
# |    policy_loss        | -34.5      |
# |    reward             | 0.46154732 |
# |    std                | 1.01       |
# |    value_loss         | 1.26       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 91          |
# |    iterations         | 2600        |
# |    time_elapsed       | 141         |
# |    total_timesteps    | 13000       |
# | train/                |             |
# |    entropy_loss       | -41.5       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2599        |
# |    policy_loss        | 14.8        |
# |    reward             | -0.08863156 |
# |    std                | 1.01        |
# |    value_loss         | 0.553       |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 91        |
# |    iterations         | 2700      |
# |    time_elapsed       | 147       |
# |    total_timesteps    | 13500     |
# | train/                |           |
# |    entropy_loss       | -41.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2699      |
# |    policy_loss        | -36.6     |
# |    reward             | 1.3793907 |
# |    std                | 1.01      |
# |    value_loss         | 1.47      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 91        |
# |    iterations         | 2800      |
# |    time_elapsed       | 153       |
# |    total_timesteps    | 14000     |
# | train/                |           |
# |    entropy_loss       | -41.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2799      |
# |    policy_loss        | 237       |
# |    reward             | 1.3057191 |
# |    std                | 1.01      |
# |    value_loss         | 41.8      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 91        |
# |    iterations         | 2900      |
# |    time_elapsed       | 158       |
# |    total_timesteps    | 14500     |
# | train/                |           |
# |    entropy_loss       | -41.5     |
# |    explained_variance | -2.77     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2899      |
# |    policy_loss        | -97       |
# |    reward             | 1.1719805 |
# |    std                | 1.01      |
# |    value_loss         | 6.11      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 91        |
# |    iterations         | 3000      |
# |    time_elapsed       | 163       |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -41.5     |
# |    explained_variance | 0.145     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2999      |
# |    policy_loss        | 100       |
# |    reward             | 1.1543376 |
# |    std                | 1.01      |
# |    value_loss         | 8.23      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 91         |
# |    iterations         | 3100       |
# |    time_elapsed       | 168        |
# |    total_timesteps    | 15500      |
# | train/                |            |
# |    entropy_loss       | -41.5      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3099       |
# |    policy_loss        | 100        |
# |    reward             | -0.1886144 |
# |    std                | 1.01       |
# |    value_loss         | 8.48       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 92          |
# |    iterations         | 3200        |
# |    time_elapsed       | 173         |
# |    total_timesteps    | 16000       |
# | train/                |             |
# |    entropy_loss       | -41.5       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 3199        |
# |    policy_loss        | 3.86        |
# |    reward             | -0.08741539 |
# |    std                | 1.01        |
# |    value_loss         | 7.46        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 92         |
# |    iterations         | 3300       |
# |    time_elapsed       | 178        |
# |    total_timesteps    | 16500      |
# | train/                |            |
# |    entropy_loss       | -41.6      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3299       |
# |    policy_loss        | 23.6       |
# |    reward             | -0.6925682 |
# |    std                | 1.02       |
# |    value_loss         | 2.61       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 92        |
# |    iterations         | 3400      |
# |    time_elapsed       | 184       |
# |    total_timesteps    | 17000     |
# | train/                |           |
# |    entropy_loss       | -41.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3399      |
# |    policy_loss        | 48.5      |
# |    reward             | 5.0184484 |
# |    std                | 1.02      |
# |    value_loss         | 7.05      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 92         |
# |    iterations         | 3500       |
# |    time_elapsed       | 189        |
# |    total_timesteps    | 17500      |
# | train/                |            |
# |    entropy_loss       | -41.6      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3499       |
# |    policy_loss        | 91.8       |
# |    reward             | -0.9813946 |
# |    std                | 1.02       |
# |    value_loss         | 8.26       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 92        |
# |    iterations         | 3600      |
# |    time_elapsed       | 194       |
# |    total_timesteps    | 18000     |
# | train/                |           |
# |    entropy_loss       | -41.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3599      |
# |    policy_loss        | -112      |
# |    reward             | 1.3530526 |
# |    std                | 1.02      |
# |    value_loss         | 9.03      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 92         |
# |    iterations         | 3700       |
# |    time_elapsed       | 199        |
# |    total_timesteps    | 18500      |
# | train/                |            |
# |    entropy_loss       | -41.6      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3699       |
# |    policy_loss        | 101        |
# |    reward             | -6.0967073 |
# |    std                | 1.02       |
# |    value_loss         | 11.7       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 92        |
# |    iterations         | 3800      |
# |    time_elapsed       | 204       |
# |    total_timesteps    | 19000     |
# | train/                |           |
# |    entropy_loss       | -41.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3799      |
# |    policy_loss        | 15.4      |
# |    reward             | 1.0199621 |
# |    std                | 1.02      |
# |    value_loss         | 1.08      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 93        |
# |    iterations         | 3900      |
# |    time_elapsed       | 209       |
# |    total_timesteps    | 19500     |
# | train/                |           |
# |    entropy_loss       | -41.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3899      |
# |    policy_loss        | -57.4     |
# |    reward             | 2.3975515 |
# |    std                | 1.02      |
# |    value_loss         | 3.17      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 93       |
# |    iterations         | 4000     |
# |    time_elapsed       | 214      |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -41.7    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | -46.5    |
# |    reward             | 3.205932 |
# |    std                | 1.02     |
# |    value_loss         | 5.6      |
# ------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 93          |
# |    iterations         | 4100        |
# |    time_elapsed       | 219         |
# |    total_timesteps    | 20500       |
# | train/                |             |
# |    entropy_loss       | -41.7       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 4099        |
# |    policy_loss        | -8.93       |
# |    reward             | 0.059854176 |
# |    std                | 1.02        |
# |    value_loss         | 2.2         |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 93           |
# |    iterations         | 4200         |
# |    time_elapsed       | 224          |
# |    total_timesteps    | 21000        |
# | train/                |              |
# |    entropy_loss       | -41.7        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 4199         |
# |    policy_loss        | -160         |
# |    reward             | -0.080707684 |
# |    std                | 1.02         |
# |    value_loss         | 18.8         |
# ----------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 93       |
# |    iterations         | 4300     |
# |    time_elapsed       | 230      |
# |    total_timesteps    | 21500    |
# | train/                |          |
# |    entropy_loss       | -41.8    |
# |    explained_variance | 0.0198   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4299     |
# |    policy_loss        | -132     |
# |    reward             | 5.925959 |
# |    std                | 1.02     |
# |    value_loss         | 11.7     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 93        |
# |    iterations         | 4400      |
# |    time_elapsed       | 236       |
# |    total_timesteps    | 22000     |
# | train/                |           |
# |    entropy_loss       | -41.8     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4399      |
# |    policy_loss        | -9.56     |
# |    reward             | 1.5270622 |
# |    std                | 1.02      |
# |    value_loss         | 5.38      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 93          |
# |    iterations         | 4500        |
# |    time_elapsed       | 241         |
# |    total_timesteps    | 22500       |
# | train/                |             |
# |    entropy_loss       | -41.8       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 4499        |
# |    policy_loss        | 377         |
# |    reward             | -0.51266694 |
# |    std                | 1.02        |
# |    value_loss         | 88.8        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 92        |
# |    iterations         | 4600      |
# |    time_elapsed       | 248       |
# |    total_timesteps    | 23000     |
# | train/                |           |
# |    entropy_loss       | -41.8     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4599      |
# |    policy_loss        | 69.3      |
# |    reward             | 3.9259188 |
# |    std                | 1.02      |
# |    value_loss         | 6.47      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 92          |
# |    iterations         | 4700        |
# |    time_elapsed       | 253         |
# |    total_timesteps    | 23500       |
# | train/                |             |
# |    entropy_loss       | -41.8       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 4699        |
# |    policy_loss        | -82.6       |
# |    reward             | -0.38894278 |
# |    std                | 1.02        |
# |    value_loss         | 6.41        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 92         |
# |    iterations         | 4800       |
# |    time_elapsed       | 258        |
# |    total_timesteps    | 24000      |
# | train/                |            |
# |    entropy_loss       | -41.9      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4799       |
# |    policy_loss        | -201       |
# |    reward             | -1.0131816 |
# |    std                | 1.03       |
# |    value_loss         | 25.1       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 93         |
# |    iterations         | 4900       |
# |    time_elapsed       | 263        |
# |    total_timesteps    | 24500      |
# | train/                |            |
# |    entropy_loss       | -41.9      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4899       |
# |    policy_loss        | -98.1      |
# |    reward             | 0.91081804 |
# |    std                | 1.03       |
# |    value_loss         | 7.56       |
# --------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 93           |
# |    iterations         | 5000         |
# |    time_elapsed       | 268          |
# |    total_timesteps    | 25000        |
# | train/                |              |
# |    entropy_loss       | -41.9        |
# |    explained_variance | 0.063        |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 4999         |
# |    policy_loss        | 56.7         |
# |    reward             | -0.117610425 |
# |    std                | 1.03         |
# |    value_loss         | 4.33         |
# ----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 93         |
# |    iterations         | 5100       |
# |    time_elapsed       | 273        |
# |    total_timesteps    | 25500      |
# | train/                |            |
# |    entropy_loss       | -41.9      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5099       |
# |    policy_loss        | 70.9       |
# |    reward             | -0.3117523 |
# |    std                | 1.03       |
# |    value_loss         | 5.32       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 93       |
# |    iterations         | 5200     |
# |    time_elapsed       | 278      |
# |    total_timesteps    | 26000    |
# | train/                |          |
# |    entropy_loss       | -41.9    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5199     |
# |    policy_loss        | -250     |
# |    reward             | 6.827836 |
# |    std                | 1.03     |
# |    value_loss         | 70.2     |
# ------------------------------------
# day: 2892, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 3486447.93
# total_reward: 2486447.93
# total_cost: 53838.40
# total_trades: 54069
# Sharpe: 0.643
# =================================
# ---------------------------------------
# | time/                 |             |
# |    fps                | 93          |
# |    iterations         | 5300        |
# |    time_elapsed       | 283         |
# |    total_timesteps    | 26500       |
# | train/                |             |
# |    entropy_loss       | -41.9       |
# |    explained_variance | -0.000586   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 5299        |
# |    policy_loss        | 25.4        |
# |    reward             | 0.017116996 |
# |    std                | 1.03        |
# |    value_loss         | 0.718       |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 93           |
# |    iterations         | 5400         |
# |    time_elapsed       | 289          |
# |    total_timesteps    | 27000        |
# | train/                |              |
# |    entropy_loss       | -41.9        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 5399         |
# |    policy_loss        | -182         |
# |    reward             | -0.075522535 |
# |    std                | 1.03         |
# |    value_loss         | 20.3         |
# ----------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 93        |
# |    iterations         | 5500      |
# |    time_elapsed       | 294       |
# |    total_timesteps    | 27500     |
# | train/                |           |
# |    entropy_loss       | -42       |
# |    explained_variance | 0.00398   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5499      |
# |    policy_loss        | -28       |
# |    reward             | 2.7373202 |
# |    std                | 1.03      |
# |    value_loss         | 18.3      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 93        |
# |    iterations         | 5600      |
# |    time_elapsed       | 299       |
# |    total_timesteps    | 28000     |
# | train/                |           |
# |    entropy_loss       | -42       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5599      |
# |    policy_loss        | -114      |
# |    reward             | 2.6049302 |
# |    std                | 1.03      |
# |    value_loss         | 11.9      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 93         |
# |    iterations         | 5700       |
# |    time_elapsed       | 304        |
# |    total_timesteps    | 28500      |
# | train/                |            |
# |    entropy_loss       | -42        |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5699       |
# |    policy_loss        | -72.5      |
# |    reward             | -0.2981388 |
# |    std                | 1.03       |
# |    value_loss         | 3.38       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 93       |
# |    iterations         | 5800     |
# |    time_elapsed       | 309      |
# |    total_timesteps    | 29000    |
# | train/                |          |
# |    entropy_loss       | -42      |
# |    explained_variance | 0.0274   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5799     |
# |    policy_loss        | -2.3     |
# |    reward             | 2.75569  |
# |    std                | 1.03     |
# |    value_loss         | 4.69     |
# ------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 93          |
# |    iterations         | 5900        |
# |    time_elapsed       | 315         |
# |    total_timesteps    | 29500       |
# | train/                |             |
# |    entropy_loss       | -41.9       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 5899        |
# |    policy_loss        | -18.6       |
# |    reward             | -0.21848644 |
# |    std                | 1.03        |
# |    value_loss         | 0.454       |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 93         |
# |    iterations         | 6000       |
# |    time_elapsed       | 320        |
# |    total_timesteps    | 30000      |
# | train/                |            |
# |    entropy_loss       | -41.9      |
# |    explained_variance | -0.132     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5999       |
# |    policy_loss        | 73.9       |
# |    reward             | -1.0408616 |
# |    std                | 1.03       |
# |    value_loss         | 4.1        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 93         |
# |    iterations         | 6100       |
# |    time_elapsed       | 325        |
# |    total_timesteps    | 30500      |
# | train/                |            |
# |    entropy_loss       | -41.9      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6099       |
# |    policy_loss        | -22.6      |
# |    reward             | -1.1798179 |
# |    std                | 1.03       |
# |    value_loss         | 1.41       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 93         |
# |    iterations         | 6200       |
# |    time_elapsed       | 330        |
# |    total_timesteps    | 31000      |
# | train/                |            |
# |    entropy_loss       | -41.9      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6199       |
# |    policy_loss        | -31.1      |
# |    reward             | -0.9238027 |
# |    std                | 1.03       |
# |    value_loss         | 0.612      |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 93       |
# |    iterations         | 6300     |
# |    time_elapsed       | 335      |
# |    total_timesteps    | 31500    |
# | train/                |          |
# |    entropy_loss       | -41.9    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6299     |
# |    policy_loss        | -32.4    |
# |    reward             | 2.290215 |
# |    std                | 1.03     |
# |    value_loss         | 2.58     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 93        |
# |    iterations         | 6400      |
# |    time_elapsed       | 340       |
# |    total_timesteps    | 32000     |
# | train/                |           |
# |    entropy_loss       | -41.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6399      |
# |    policy_loss        | 110       |
# |    reward             | 2.4718473 |
# |    std                | 1.03      |
# |    value_loss         | 7.32      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 94        |
# |    iterations         | 6500      |
# |    time_elapsed       | 345       |
# |    total_timesteps    | 32500     |
# | train/                |           |
# |    entropy_loss       | -42       |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6499      |
# |    policy_loss        | -13.3     |
# |    reward             | -4.768291 |
# |    std                | 1.03      |
# |    value_loss         | 5.25      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 94        |
# |    iterations         | 6600      |
# |    time_elapsed       | 350       |
# |    total_timesteps    | 33000     |
# | train/                |           |
# |    entropy_loss       | -42.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6599      |
# |    policy_loss        | -82.3     |
# |    reward             | 0.2020581 |
# |    std                | 1.03      |
# |    value_loss         | 8.15      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 94         |
# |    iterations         | 6700       |
# |    time_elapsed       | 355        |
# |    total_timesteps    | 33500      |
# | train/                |            |
# |    entropy_loss       | -42        |
# |    explained_variance | 0.000169   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6699       |
# |    policy_loss        | -715       |
# |    reward             | -6.8108516 |
# |    std                | 1.03       |
# |    value_loss         | 377        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 94         |
# |    iterations         | 6800       |
# |    time_elapsed       | 360        |
# |    total_timesteps    | 34000      |
# | train/                |            |
# |    entropy_loss       | -42        |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6799       |
# |    policy_loss        | -124       |
# |    reward             | 0.48438752 |
# |    std                | 1.03       |
# |    value_loss         | 10.6       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 94          |
# |    iterations         | 6900        |
# |    time_elapsed       | 365         |
# |    total_timesteps    | 34500       |
# | train/                |             |
# |    entropy_loss       | -42         |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 6899        |
# |    policy_loss        | -277        |
# |    reward             | -0.42972565 |
# |    std                | 1.03        |
# |    value_loss         | 63.7        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 94         |
# |    iterations         | 7000       |
# |    time_elapsed       | 370        |
# |    total_timesteps    | 35000      |
# | train/                |            |
# |    entropy_loss       | -42        |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6999       |
# |    policy_loss        | 44.1       |
# |    reward             | 0.33409375 |
# |    std                | 1.03       |
# |    value_loss         | 1.66       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 94         |
# |    iterations         | 7100       |
# |    time_elapsed       | 375        |
# |    total_timesteps    | 35500      |
# | train/                |            |
# |    entropy_loss       | -42.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7099       |
# |    policy_loss        | 91.6       |
# |    reward             | 0.40660557 |
# |    std                | 1.03       |
# |    value_loss         | 6.77       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 94         |
# |    iterations         | 7200       |
# |    time_elapsed       | 380        |
# |    total_timesteps    | 36000      |
# | train/                |            |
# |    entropy_loss       | -42.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7199       |
# |    policy_loss        | -340       |
# |    reward             | 0.17403442 |
# |    std                | 1.04       |
# |    value_loss         | 74.9       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 94        |
# |    iterations         | 7300      |
# |    time_elapsed       | 385       |
# |    total_timesteps    | 36500     |
# | train/                |           |
# |    entropy_loss       | -42.2     |
# |    explained_variance | -8.34e-06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7299      |
# |    policy_loss        | -123      |
# |    reward             | 1.7243018 |
# |    std                | 1.04      |
# |    value_loss         | 14.7      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 94        |
# |    iterations         | 7400      |
# |    time_elapsed       | 390       |
# |    total_timesteps    | 37000     |
# | train/                |           |
# |    entropy_loss       | -42.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7399      |
# |    policy_loss        | 15.7      |
# |    reward             | -7.561226 |
# |    std                | 1.04      |
# |    value_loss         | 2.12      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 94        |
# |    iterations         | 7500      |
# |    time_elapsed       | 395       |
# |    total_timesteps    | 37500     |
# | train/                |           |
# |    entropy_loss       | -42.2     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7499      |
# |    policy_loss        | 286       |
# |    reward             | -8.332817 |
# |    std                | 1.04      |
# |    value_loss         | 63        |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 94         |
# |    iterations         | 7600       |
# |    time_elapsed       | 402        |
# |    total_timesteps    | 38000      |
# | train/                |            |
# |    entropy_loss       | -42.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7599       |
# |    policy_loss        | -13.8      |
# |    reward             | 0.75812984 |
# |    std                | 1.04       |
# |    value_loss         | 1.74       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 94         |
# |    iterations         | 7700       |
# |    time_elapsed       | 407        |
# |    total_timesteps    | 38500      |
# | train/                |            |
# |    entropy_loss       | -42.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7699       |
# |    policy_loss        | -33.7      |
# |    reward             | 0.42178074 |
# |    std                | 1.04       |
# |    value_loss         | 0.958      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 94        |
# |    iterations         | 7800      |
# |    time_elapsed       | 412       |
# |    total_timesteps    | 39000     |
# | train/                |           |
# |    entropy_loss       | -42.3     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7799      |
# |    policy_loss        | -136      |
# |    reward             | 1.0603276 |
# |    std                | 1.04      |
# |    value_loss         | 10.7      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 94        |
# |    iterations         | 7900      |
# |    time_elapsed       | 417       |
# |    total_timesteps    | 39500     |
# | train/                |           |
# |    entropy_loss       | -42.4     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7899      |
# |    policy_loss        | 168       |
# |    reward             | 3.3499734 |
# |    std                | 1.05      |
# |    value_loss         | 41.9      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 94         |
# |    iterations         | 8000       |
# |    time_elapsed       | 422        |
# |    total_timesteps    | 40000      |
# | train/                |            |
# |    entropy_loss       | -42.4      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7999       |
# |    policy_loss        | -120       |
# |    reward             | -2.5226536 |
# |    std                | 1.05       |
# |    value_loss         | 12.1       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 94       |
# |    iterations         | 8100     |
# |    time_elapsed       | 427      |
# |    total_timesteps    | 40500    |
# | train/                |          |
# |    entropy_loss       | -42.5    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8099     |
# |    policy_loss        | -222     |
# |    reward             | 5.657979 |
# |    std                | 1.05     |
# |    value_loss         | 40.2     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 94         |
# |    iterations         | 8200       |
# |    time_elapsed       | 432        |
# |    total_timesteps    | 41000      |
# | train/                |            |
# |    entropy_loss       | -42.5      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8199       |
# |    policy_loss        | -56.9      |
# |    reward             | -0.3537702 |
# |    std                | 1.05       |
# |    value_loss         | 2.31       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 94         |
# |    iterations         | 8300       |
# |    time_elapsed       | 437        |
# |    total_timesteps    | 41500      |
# | train/                |            |
# |    entropy_loss       | -42.5      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8299       |
# |    policy_loss        | -36        |
# |    reward             | -1.6973335 |
# |    std                | 1.05       |
# |    value_loss         | 0.756      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 94         |
# |    iterations         | 8400       |
# |    time_elapsed       | 442        |
# |    total_timesteps    | 42000      |
# | train/                |            |
# |    entropy_loss       | -42.6      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8399       |
# |    policy_loss        | 24.3       |
# |    reward             | -2.3691933 |
# |    std                | 1.05       |
# |    value_loss         | 0.798      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 94        |
# |    iterations         | 8500      |
# |    time_elapsed       | 447       |
# |    total_timesteps    | 42500     |
# | train/                |           |
# |    entropy_loss       | -42.5     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8499      |
# |    policy_loss        | 113       |
# |    reward             | 1.8273059 |
# |    std                | 1.05      |
# |    value_loss         | 7.59      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 94        |
# |    iterations         | 8600      |
# |    time_elapsed       | 452       |
# |    total_timesteps    | 43000     |
# | train/                |           |
# |    entropy_loss       | -42.5     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8599      |
# |    policy_loss        | 127       |
# |    reward             | -8.170493 |
# |    std                | 1.05      |
# |    value_loss         | 19.4      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 94        |
# |    iterations         | 8700      |
# |    time_elapsed       | 457       |
# |    total_timesteps    | 43500     |
# | train/                |           |
# |    entropy_loss       | -42.5     |
# |    explained_variance | -0.0121   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8699      |
# |    policy_loss        | 70.6      |
# |    reward             | 1.9999367 |
# |    std                | 1.05      |
# |    value_loss         | 4.03      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 95        |
# |    iterations         | 8800      |
# |    time_elapsed       | 462       |
# |    total_timesteps    | 44000     |
# | train/                |           |
# |    entropy_loss       | -42.5     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8799      |
# |    policy_loss        | -73.1     |
# |    reward             | 0.8715767 |
# |    std                | 1.05      |
# |    value_loss         | 2.9       |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 95       |
# |    iterations         | 8900     |
# |    time_elapsed       | 468      |
# |    total_timesteps    | 44500    |
# | train/                |          |
# |    entropy_loss       | -42.5    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8899     |
# |    policy_loss        | 108      |
# |    reward             | 1.500559 |
# |    std                | 1.05     |
# |    value_loss         | 8.87     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 95         |
# |    iterations         | 9000       |
# |    time_elapsed       | 473        |
# |    total_timesteps    | 45000      |
# | train/                |            |
# |    entropy_loss       | -42.5      |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8999       |
# |    policy_loss        | 24.2       |
# |    reward             | -0.8812128 |
# |    std                | 1.05       |
# |    value_loss         | 2.27       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 95        |
# |    iterations         | 9100      |
# |    time_elapsed       | 478       |
# |    total_timesteps    | 45500     |
# | train/                |           |
# |    entropy_loss       | -42.5     |
# |    explained_variance | 0.0267    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9099      |
# |    policy_loss        | -39.9     |
# |    reward             | 1.6348946 |
# |    std                | 1.05      |
# |    value_loss         | 0.967     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 94        |
# |    iterations         | 9200      |
# |    time_elapsed       | 484       |
# |    total_timesteps    | 46000     |
# | train/                |           |
# |    entropy_loss       | -42.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9199      |
# |    policy_loss        | 63.2      |
# |    reward             | 2.4694052 |
# |    std                | 1.05      |
# |    value_loss         | 3.35      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 95          |
# |    iterations         | 9300        |
# |    time_elapsed       | 489         |
# |    total_timesteps    | 46500       |
# | train/                |             |
# |    entropy_loss       | -42.5       |
# |    explained_variance | 0.00554     |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 9299        |
# |    policy_loss        | -154        |
# |    reward             | -0.09315522 |
# |    std                | 1.05        |
# |    value_loss         | 15.9        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 94          |
# |    iterations         | 9400        |
# |    time_elapsed       | 497         |
# |    total_timesteps    | 47000       |
# | train/                |             |
# |    entropy_loss       | -42.5       |
# |    explained_variance | -0.104      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 9399        |
# |    policy_loss        | 103         |
# |    reward             | -0.35163647 |
# |    std                | 1.05        |
# |    value_loss         | 7.03        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 94         |
# |    iterations         | 9500       |
# |    time_elapsed       | 504        |
# |    total_timesteps    | 47500      |
# | train/                |            |
# |    entropy_loss       | -42.5      |
# |    explained_variance | 0.0299     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9499       |
# |    policy_loss        | -39.6      |
# |    reward             | 0.82362926 |
# |    std                | 1.05       |
# |    value_loss         | 2.14       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 94         |
# |    iterations         | 9600       |
# |    time_elapsed       | 510        |
# |    total_timesteps    | 48000      |
# | train/                |            |
# |    entropy_loss       | -42.5      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9599       |
# |    policy_loss        | -119       |
# |    reward             | -2.3924477 |
# |    std                | 1.05       |
# |    value_loss         | 8.37       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 94       |
# |    iterations         | 9700     |
# |    time_elapsed       | 515      |
# |    total_timesteps    | 48500    |
# | train/                |          |
# |    entropy_loss       | -42.6    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9699     |
# |    policy_loss        | -79.4    |
# |    reward             | 1.908087 |
# |    std                | 1.05     |
# |    value_loss         | 4.64     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 94        |
# |    iterations         | 9800      |
# |    time_elapsed       | 520       |
# |    total_timesteps    | 49000     |
# | train/                |           |
# |    entropy_loss       | -42.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9799      |
# |    policy_loss        | -73.5     |
# |    reward             | 4.1685767 |
# |    std                | 1.05      |
# |    value_loss         | 30.7      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 94          |
# |    iterations         | 9900        |
# |    time_elapsed       | 525         |
# |    total_timesteps    | 49500       |
# | train/                |             |
# |    entropy_loss       | -42.6       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 9899        |
# |    policy_loss        | 31.7        |
# |    reward             | -0.19541535 |
# |    std                | 1.05        |
# |    value_loss         | 0.952       |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 94          |
# |    iterations         | 10000       |
# |    time_elapsed       | 530         |
# |    total_timesteps    | 50000       |
# | train/                |             |
# |    entropy_loss       | -42.6       |
# |    explained_variance | 1.19e-07    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 9999        |
# |    policy_loss        | 32.6        |
# |    reward             | -0.88383603 |
# |    std                | 1.05        |
# |    value_loss         | 1.46        |
# ---------------------------------------

# %% [markdown]
# # **2) Deep Deterministic Policy Gradient**

# %%
// TODO

# %% [markdown]
# # **3) Proximal Policy Optimization**

# %% [markdown]
# $$L^{\text{CLIP}}(\theta)=\hat{\mathbb{E}} \left[ \min(r_t(\theta)\hat{A}_t, \text{clip}(r_t(\theta),1-\epsilon,1+\epsilon)\hat{A}_t) \right]$$

# %%
// TODO

# %% [markdown]
# # **4) Twin Delayes Deep Deterministic Policy Gradient**

# %%
// TODO

# %% [markdown]
# # **5) Soft Actor Critic**

# %%
// TODO
